# %% [markdown]
# # Worksheet 3: PostgreSQL data manipulation

# %%
import numpy as np
import pandas as pd
# %load_ext sql
# %config SqlMagic.displaylimit = 20
# %config SqlMagic.autolimit = 30

# %% [markdown]
# #### Exercise 1: Connect to the `dvdrental` Database and Data Type Conversion
# 1. **Connect to the `dvdrental` Database**:
#    - Connect to the `dvdrental` database

# %%
# load the credentials from the credentials.json file
import json
import urllib.parse

with open('data/credentials.json') as f:
    login = json.load(f)
    
username = login['user']
password = urllib.parse.quote(login['password'])
host = login['host']
port = login['port']

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/dvdrental
# Out:
# 'Connected: postgres@dvdrental'

# %% [markdown]
# Print out the first 10 rows of the `rental` table.

# %%
# %%sql
#    SELECT * FROM rental LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 10 rows affected.
# [(2, datetime.datetime(2005, 5, 24, 22, 54, 33), 1525, 459, datetime.datetime(2005, 5, 28, 19, 40, 33), 1, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (3, datetime.datetime(2005, 5, 24, 23, 3, 39), 1711, 408, datetime.datetime(2005, 6, 1, 22, 12, 39), 1, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (4, datetime.datetime(2005, 5, 24, 23, 4, 41), 2452, 333, datetime.datetime(2005, 6, 3, 1, 43, 41), 2, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (5, datetime.datetime(2005, 5, 24, 23, 5, 21), 2079, 222, datetime.datetime(2005, 6, 2, 4, 33, 21), 1, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (6, datetime.datetime(2005, 5, 24, 23, 8, 7), 2792, 549, datetime.datetime(2005, 5, 27, 1, 32, 7), 1, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (7, datetime.datetime(2005, 5, 24, 23, 11, 53), 3995, 269, datetime.datetime(2005, 5, 29, 20, 34, 53), 2, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (8, datetime.datetime(2005, 5, 24, 23, 31, 46), 2346, 239, datetime.datetime(2005, 5, 27, 23, 33, 46), 2, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (9, datetime.datetime(2005, 5, 25, 0, 0, 40), 2580, 126, datetime.datetime(2005, 5, 28, 0, 22, 40), 1, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (10, datetime.datetime(2005, 5, 25, 0, 2, 21), 1824, 399, datetime.datetime(2005, 5, 31, 22, 44, 21), 2, datetime.datetime(2006, 2, 16, 2, 30, 53)),
#  (11, datetime.datetime(2005, 5, 25, 0, 9, 2), 4443, 142, datetime.datetime(2005, 6, 2, 20, 56, 2), 2, datetime.datetime(2006, 2, 16, 2, 30, 53))]

# %% [markdown]
# List all columns and its data type in the `rental` table.
# > Hint: see the [lecture 4 notes for example](https://tru-dasc.github.io/DASC_5410_students/lectures/lecture4.html#connect-to-database)

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_name = 'rental';
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 7 rows affected.
# [('rental_id', 'integer'),
#  ('rental_date', 'timestamp without time zone'),
#  ('inventory_id', 'integer'),
#  ('customer_id', 'smallint'),
#  ('return_date', 'timestamp without time zone'),
#  ('staff_id', 'smallint'),
#  ('last_update', 'timestamp without time zone')]

# %% [markdown]
# 2. **Convert Between Data Types**:
#    - Convert the `rental_date` column in the `rental` table to a string

# %%
# %%sql
# SELECT rental_date::TEXT
# FROM rental
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 16044 rows affected.
# [('2005-05-24 22:54:33',),
#  ('2005-05-24 23:03:39',),
#  ('2005-05-24 23:04:41',),
#  ('2005-05-24 23:05:21',),
#  ('2005-05-24 23:08:07',),
#  ('2005-05-24 23:11:53',),
#  ('2005-05-24 23:31:46',),
#  ('2005-05-25 00:00:40',),
#  ('2005-05-25 00:02:21',),
#  ('2005-05-25 00:09:02',),
#  ('2005-05-25 00:19:27',),
#  ('2005-05-25 00:22:55',),
#  ('2005-05-25 00:31:15',),
#  ('2005-05-25 00:39:22',),
#  ('2005-05-25 00:43:11',),
#  ('2005-05-25 01:06:36',),
#  ('2005-05-25 01:10:47',),
#  ('2005-05-25 01:17:24',),
#  ('2005-05-25 01:48:41',),
#  ('2005-05-25 01:59:46',),
#  ('2005-05-25 02:19:23',),
#  ('2005-05-25 02:40:21',),
#  ('2005-05-25 02:53:02',),
#  ('2005-05-25 03:21:20',),
#  ('2005-05-25 03:36:50',),
#  ('2005-05-25 03:41:50',),
#  ('2005-05-25 03:42:37',),
#  ('2005-05-25 03:47:12',),
#  ('2005-05-25 04:01:32',),
#  ('2005-05-25 04:05:17',)]

# %% [markdown]
# #### Exercise 2: Filtering Rows Using `WHERE`
# 1. **Filter Using `BETWEEN`**:
#    - Filter the `payment` table where the `amount` is between 5 and 10.

# %%
# %%sql
# SELECT *
# FROM payment
# WHERE amount BETWEEN 5 AND 10
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 3511 rows affected.
# [(17503, 341, 2, 1520, Decimal('7.99'), datetime.datetime(2007, 2, 15, 22, 25, 46, 996577)),
#  (17505, 341, 1, 1849, Decimal('7.99'), datetime.datetime(2007, 2, 16, 22, 41, 45, 996577)),
#  (17507, 341, 2, 3130, Decimal('7.99'), datetime.datetime(2007, 2, 20, 17, 31, 48, 996577)),
#  (17508, 341, 1, 3382, Decimal('5.99'), datetime.datetime(2007, 2, 21, 12, 33, 49, 996577)),
#  (17509, 342, 2, 2190, Decimal('5.99'), datetime.datetime(2007, 2, 17, 23, 58, 17, 996577)),
#  (17510, 342, 1, 2914, Decimal('5.99'), datetime.datetime(2007, 2, 20, 2, 11, 44, 996577)),
#  (17513, 343, 1, 1564, Decimal('6.99'), datetime.datetime(2007, 2, 16, 1, 15, 33, 996577)),
#  (17516, 343, 2, 2461, Decimal('6.99'), datetime.datetime(2007, 2, 18, 18, 26, 38, 996577)),
#  (17517, 343, 1, 2980, Decimal('8.99'), datetime.datetime(2007, 2, 20, 7, 3, 29, 996577)),
#  (17526, 346, 1, 1994, Decimal('5.99'), datetime.datetime(2007, 2, 17, 9, 35, 32, 996577)),
#  (17529, 347, 2, 1711, Decimal('8.99'), datetime.datetime(2007, 2, 16, 12, 40, 18, 996577)),
#  (17532, 347, 1, 3092, Decimal('8.99'), datetime.datetime(2007, 2, 20, 14, 33, 8, 996577)),
#  (17533, 347, 1, 3326, Decimal('7.99'), datetime.datetime(2007, 2, 21, 7, 33, 16, 996577)),
#  (17535, 348, 1, 2041, Decimal('8.99'), datetime.datetime(2007, 2, 17, 12, 47, 26, 996577)),
#  (17539, 349, 2, 2987, Decimal('6.99'), datetime.datetime(2007, 2, 20, 7, 24, 16, 996577)),
#  (17540, 349, 1, 3067, Decimal('8.99'), datetime.datetime(2007, 2, 20, 12, 27, 47, 996577)),
#  (17545, 351, 2, 1792, Decimal('5.99'), datetime.datetime(2007, 2, 16, 18, 33, 16, 996577)),
#  (17554, 353, 2, 1928, Decimal('7.99'), datetime.datetime(2007, 2, 17, 5, 16, 57, 996577)),
#  (17555, 353, 2, 3233, Decimal('6.99'), datetime.datetime(2007, 2, 21, 1, 7, 57, 996577)),
#  (17558, 354, 1, 2769, Decimal('6.99'), datetime.datetime(2007, 2, 19, 16, 20, 40, 996577)),
#  (17565, 357, 2, 1246, Decimal('5.99'), datetime.datetime(2007, 2, 15, 3, 39, 45, 996577)),
#  (17568, 357, 2, 2153, Decimal('6.99'), datetime.datetime(2007, 2, 17, 21, 26, 30, 996577)),
#  (17571, 358, 1, 2114, Decimal('5.99'), datetime.datetime(2007, 2, 17, 18, 28, 51, 996577)),
#  (17580, 360, 2, 2402, Decimal('6.99'), datetime.datetime(2007, 2, 18, 14, 53, 11, 996577)),
#  (17582, 360, 2, 2780, Decimal('6.99'), datetime.datetime(2007, 2, 19, 16, 47, 59, 996577)),
#  (17603, 365, 1, 1578, Decimal('6.99'), datetime.datetime(2007, 2, 16, 2, 36, 42, 996577)),
#  (17611, 368, 1, 1513, Decimal('9.99'), datetime.datetime(2007, 2, 15, 21, 21, 56, 996577)),
#  (17617, 370, 2, 1190, Decimal('6.99'), datetime.datetime(2007, 2, 14, 23, 33, 58, 996577)),
#  (17620, 371, 1, 1573, Decimal('6.99'), datetime.datetime(2007, 2, 16, 2, 0, 5, 996577)),
#  (17621, 371, 2, 1675, Decimal('5.99'), datetime.datetime(2007, 2, 16, 9, 33, 13, 996577))]

# %% [markdown]
#    - Filter the `payment` table where the `paymen_date` is between 2007-02-17 and 2007-02-18.

# %%
# %%sql
# SELECT *
# FROM payment
# WHERE payment_date BETWEEN '2007-02-17' AND '2007-02-18'
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 283 rows affected.
# [(17509, 342, 2, 2190, Decimal('5.99'), datetime.datetime(2007, 2, 17, 23, 58, 17, 996577)),
#  (17514, 343, 2, 1879, Decimal('0.99'), datetime.datetime(2007, 2, 17, 1, 26, 0, 996577)),
#  (17515, 343, 2, 1922, Decimal('0.99'), datetime.datetime(2007, 2, 17, 4, 32, 51, 996577)),
#  (17526, 346, 1, 1994, Decimal('5.99'), datetime.datetime(2007, 2, 17, 9, 35, 32, 996577)),
#  (17535, 348, 1, 2041, Decimal('8.99'), datetime.datetime(2007, 2, 17, 12, 47, 26, 996577)),
#  (17541, 350, 2, 2011, Decimal('3.99'), datetime.datetime(2007, 2, 17, 10, 24, 35, 996577)),
#  (17546, 351, 1, 1869, Decimal('0.99'), datetime.datetime(2007, 2, 17, 0, 36, 26, 996577)),
#  (17554, 353, 2, 1928, Decimal('7.99'), datetime.datetime(2007, 2, 17, 5, 16, 57, 996577)),
#  (17567, 357, 2, 1971, Decimal('1.99'), datetime.datetime(2007, 2, 17, 7, 52, 25, 996577)),
#  (17568, 357, 2, 2153, Decimal('6.99'), datetime.datetime(2007, 2, 17, 21, 26, 30, 996577)),
#  (17570, 358, 2, 1908, Decimal('0.99'), datetime.datetime(2007, 2, 17, 3, 39, 2, 996577)),
#  (17571, 358, 1, 2114, Decimal('5.99'), datetime.datetime(2007, 2, 17, 18, 28, 51, 996577)),
#  (17604, 365, 1, 1983, Decimal('4.99'), datetime.datetime(2007, 2, 17, 8, 50, 39, 996577)),
#  (17631, 374, 2, 2046, Decimal('1.99'), datetime.datetime(2007, 2, 17, 13, 8, 16, 996577)),
#  (17646, 378, 2, 2134, Decimal('7.99'), datetime.datetime(2007, 2, 17, 19, 42, 10, 996577)),
#  (17651, 380, 1, 1868, Decimal('3.99'), datetime.datetime(2007, 2, 17, 0, 31, 48, 996577)),
#  (17652, 380, 1, 1984, Decimal('2.99'), datetime.datetime(2007, 2, 17, 8, 53, 54, 996577)),
#  (17653, 380, 1, 2018, Decimal('3.99'), datetime.datetime(2007, 2, 17, 11, 4, 24, 996577)),
#  (17660, 381, 1, 1878, Decimal('1.99'), datetime.datetime(2007, 2, 17, 1, 23, 58, 996577)),
#  (17675, 384, 1, 1961, Decimal('0.99'), datetime.datetime(2007, 2, 17, 7, 31, 24, 996577)),
#  (17676, 384, 2, 2020, Decimal('0.99'), datetime.datetime(2007, 2, 17, 11, 8, 16, 996577)),
#  (17683, 385, 1, 1937, Decimal('0.99'), datetime.datetime(2007, 2, 17, 5, 45, 12, 996577)),
#  (17692, 387, 1, 2068, Decimal('0.99'), datetime.datetime(2007, 2, 17, 14, 40, 12, 996577)),
#  (17693, 387, 2, 2100, Decimal('0.99'), datetime.datetime(2007, 2, 17, 17, 21, 47, 996577)),
#  (17697, 388, 1, 2145, Decimal('0.99'), datetime.datetime(2007, 2, 17, 20, 39, 2, 996577)),
#  (17702, 389, 1, 1946, Decimal('4.99'), datetime.datetime(2007, 2, 17, 6, 27, 5, 996577)),
#  (17706, 390, 2, 1893, Decimal('2.99'), datetime.datetime(2007, 2, 17, 2, 47, 3, 996577)),
#  (17710, 391, 2, 1931, Decimal('0.99'), datetime.datetime(2007, 2, 17, 5, 20, 22, 996577)),
#  (17711, 391, 1, 2045, Decimal('2.99'), datetime.datetime(2007, 2, 17, 13, 6, 37, 996577)),
#  (17719, 393, 2, 1915, Decimal('1.99'), datetime.datetime(2007, 2, 17, 3, 56, 54, 996577))]

# %% [markdown]
# 2. **Filter Using `IN`**:
#    - Select the rows from the `customer` table where the `first_name` is either 'Tracy' or 'Kelly'

# %%
# %%sql
# SELECT *
# FROM customer
# WHERE first_name in ('Tracy', 'Kelly')
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 4 rows affected.
# [(67, 1, 'Kelly', 'Torres', 'kelly.torres@sakilacustomer.org', 71, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (108, 1, 'Tracy', 'Cole', 'tracy.cole@sakilacustomer.org', 112, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (546, 1, 'Kelly', 'Knott', 'kelly.knott@sakilacustomer.org', 552, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (589, 1, 'Tracy', 'Herrmann', 'tracy.herrmann@sakilacustomer.org', 595, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)]

# %% [markdown]
# 3. **Filter Using `LIKE`**:
#    - Select the rows from the `customer` table where the `first_name` have 4 characters and ends with 'e'

# %%
# %%sql
# SELECT *
# FROM customer
# WHERE first_name LIKE '___e'
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 12 rows affected.
# [(65, 2, 'Rose', 'Howard', 'rose.howard@sakilacustomer.org', 69, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (77, 2, 'Jane', 'Bennett', 'jane.bennett@sakilacustomer.org', 81, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (85, 2, 'Anne', 'Powell', 'anne.powell@sakilacustomer.org', 89, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (176, 1, 'June', 'Carroll', 'june.carroll@sakilacustomer.org', 180, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (326, 1, 'Jose', 'Andrew', 'jose.andrew@sakilacustomer.org', 331, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (403, 1, 'Mike', 'Way', 'mike.way@sakilacustomer.org', 408, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (407, 1, 'Dale', 'Ratcliff', 'dale.ratcliff@sakilacustomer.org', 412, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (424, 2, 'Kyle', 'Spurlock', 'kyle.spurlock@sakilacustomer.org', 429, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (498, 1, 'Gene', 'Sanborn', 'gene.sanborn@sakilacustomer.org', 503, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (569, 2, 'Dave', 'Gardiner', 'dave.gardiner@sakilacustomer.org', 575, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (593, 2, 'Rene', 'Mcalister', 'rene.mcalister@sakilacustomer.org', 599, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (598, 1, 'Wade', 'Delvalle', 'wade.delvalle@sakilacustomer.org', 604, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)]

# %% [markdown]
# Select the rows from the `customer` table where
#    - `first_name` DO NOT ends with 'e' AND
#    - `last_name` starts with 'E'

# %%
# %%sql
# SELECT *
# FROM customer
# WHERE first_name NOT LIKE '%e' AND last_name LIKE 'E%'
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 9 rows affected.
# [(524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (48, 1, 'Ann', 'Evans', 'ann.evans@sakilacustomer.org', 52, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (417, 1, 'Travis', 'Estep', 'travis.estep@sakilacustomer.org', 422, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (418, 2, 'Jeff', 'East', 'jeff.east@sakilacustomer.org', 423, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (422, 1, 'Melvin', 'Ellington', 'melvin.ellington@sakilacustomer.org', 427, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (466, 1, 'Leo', 'Ebert', 'leo.ebert@sakilacustomer.org', 471, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (510, 2, 'Ben', 'Easter', 'ben.easter@sakilacustomer.org', 515, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0),
#  (535, 1, 'Javier', 'Elrod', 'javier.elrod@sakilacustomer.org', 541, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (547, 1, 'Kurt', 'Emmons', 'kurt.emmons@sakilacustomer.org', 553, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1)]

# %% [markdown]
# #### Exercise 3: Derived Columns
# 1. **Concatenate Columns**:
#    - Concatenate the `first_name` and `last_name` columns and turn all into lower cases
#    - Store them in a new column called `full_name`

# %%
# %%sql
# SELECT
#    first_name,
#    last_name,
#    LOWER(CONCAT(first_name, last_name)) AS full_name
# FROM customer
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 599 rows affected.
# [('Jared', 'Ely', 'jaredely'),
#  ('Mary', 'Smith', 'marysmith'),
#  ('Patricia', 'Johnson', 'patriciajohnson'),
#  ('Linda', 'Williams', 'lindawilliams'),
#  ('Barbara', 'Jones', 'barbarajones'),
#  ('Elizabeth', 'Brown', 'elizabethbrown'),
#  ('Jennifer', 'Davis', 'jenniferdavis'),
#  ('Maria', 'Miller', 'mariamiller'),
#  ('Susan', 'Wilson', 'susanwilson'),
#  ('Margaret', 'Moore', 'margaretmoore'),
#  ('Dorothy', 'Taylor', 'dorothytaylor'),
#  ('Lisa', 'Anderson', 'lisaanderson'),
#  ('Nancy', 'Thomas', 'nancythomas'),
#  ('Karen', 'Jackson', 'karenjackson'),
#  ('Betty', 'White', 'bettywhite'),
#  ('Helen', 'Harris', 'helenharris'),
#  ('Sandra', 'Martin', 'sandramartin'),
#  ('Donna', 'Thompson', 'donnathompson'),
#  ('Carol', 'Garcia', 'carolgarcia'),
#  ('Ruth', 'Martinez', 'ruthmartinez'),
#  ('Sharon', 'Robinson', 'sharonrobinson'),
#  ('Michelle', 'Clark', 'michelleclark'),
#  ('Laura', 'Rodriguez', 'laurarodriguez'),
#  ('Sarah', 'Lewis', 'sarahlewis'),
#  ('Kimberly', 'Lee', 'kimberlylee'),
#  ('Deborah', 'Walker', 'deborahwalker'),
#  ('Jessica', 'Hall', 'jessicahall'),
#  ('Shirley', 'Allen', 'shirleyallen'),
#  ('Cynthia', 'Young', 'cynthiayoung'),
#  ('Angela', 'Hernandez', 'angelahernandez')]

# %% [markdown]
# 2. **Arithmetic Operations**:
#    - Calculate the payment amount assuming a discount rate of 15%
#    - Store them in a new column called `discount_payment`

# %%
# %%sql
# SELECT
#    *,
#    TRUNC((1-0.15)*amount,2) as discount_payment
# FROM payment
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 14596 rows affected.
# [(17503, 341, 2, 1520, Decimal('7.99'), datetime.datetime(2007, 2, 15, 22, 25, 46, 996577), Decimal('6.79')),
#  (17504, 341, 1, 1778, Decimal('1.99'), datetime.datetime(2007, 2, 16, 17, 23, 14, 996577), Decimal('1.69')),
#  (17505, 341, 1, 1849, Decimal('7.99'), datetime.datetime(2007, 2, 16, 22, 41, 45, 996577), Decimal('6.79')),
#  (17506, 341, 2, 2829, Decimal('2.99'), datetime.datetime(2007, 2, 19, 19, 39, 56, 996577), Decimal('2.54')),
#  (17507, 341, 2, 3130, Decimal('7.99'), datetime.datetime(2007, 2, 20, 17, 31, 48, 996577), Decimal('6.79')),
#  (17508, 341, 1, 3382, Decimal('5.99'), datetime.datetime(2007, 2, 21, 12, 33, 49, 996577), Decimal('5.09')),
#  (17509, 342, 2, 2190, Decimal('5.99'), datetime.datetime(2007, 2, 17, 23, 58, 17, 996577), Decimal('5.09')),
#  (17510, 342, 1, 2914, Decimal('5.99'), datetime.datetime(2007, 2, 20, 2, 11, 44, 996577), Decimal('5.09')),
#  (17511, 342, 1, 3081, Decimal('2.99'), datetime.datetime(2007, 2, 20, 13, 57, 39, 996577), Decimal('2.54')),
#  (17512, 343, 2, 1547, Decimal('4.99'), datetime.datetime(2007, 2, 16, 0, 10, 50, 996577), Decimal('4.24')),
#  (17513, 343, 1, 1564, Decimal('6.99'), datetime.datetime(2007, 2, 16, 1, 15, 33, 996577), Decimal('5.94')),
#  (17514, 343, 2, 1879, Decimal('0.99'), datetime.datetime(2007, 2, 17, 1, 26, 0, 996577), Decimal('0.84')),
#  (17515, 343, 2, 1922, Decimal('0.99'), datetime.datetime(2007, 2, 17, 4, 32, 51, 996577), Decimal('0.84')),
#  (17516, 343, 2, 2461, Decimal('6.99'), datetime.datetime(2007, 2, 18, 18, 26, 38, 996577), Decimal('5.94')),
#  (17517, 343, 1, 2980, Decimal('8.99'), datetime.datetime(2007, 2, 20, 7, 3, 29, 996577), Decimal('7.64')),
#  (17518, 343, 1, 3407, Decimal('0.99'), datetime.datetime(2007, 2, 21, 14, 42, 28, 996577), Decimal('0.84')),
#  (17519, 344, 1, 1341, Decimal('3.99'), datetime.datetime(2007, 2, 15, 10, 54, 44, 996577), Decimal('3.39')),
#  (17520, 344, 2, 1475, Decimal('4.99'), datetime.datetime(2007, 2, 15, 19, 36, 27, 996577), Decimal('4.24')),
#  (17521, 344, 1, 1731, Decimal('0.99'), datetime.datetime(2007, 2, 16, 14, 0, 38, 996577), Decimal('0.84')),
#  (17522, 345, 2, 1210, Decimal('0.99'), datetime.datetime(2007, 2, 15, 1, 26, 17, 996577), Decimal('0.84')),
#  (17523, 345, 1, 1457, Decimal('4.99'), datetime.datetime(2007, 2, 15, 18, 34, 15, 996577), Decimal('4.24')),
#  (17524, 345, 2, 1550, Decimal('0.99'), datetime.datetime(2007, 2, 16, 0, 27, 1, 996577), Decimal('0.84')),
#  (17525, 345, 2, 2766, Decimal('4.99'), datetime.datetime(2007, 2, 19, 16, 13, 41, 996577), Decimal('4.24')),
#  (17526, 346, 1, 1994, Decimal('5.99'), datetime.datetime(2007, 2, 17, 9, 35, 32, 996577), Decimal('5.09')),
#  (17527, 346, 2, 3372, Decimal('2.99'), datetime.datetime(2007, 2, 21, 12, 2, 45, 996577), Decimal('2.54')),
#  (17528, 346, 1, 3421, Decimal('2.99'), datetime.datetime(2007, 2, 21, 15, 51, 24, 996577), Decimal('2.54')),
#  (17529, 347, 2, 1711, Decimal('8.99'), datetime.datetime(2007, 2, 16, 12, 40, 18, 996577), Decimal('7.64')),
#  (17530, 347, 2, 2274, Decimal('0.99'), datetime.datetime(2007, 2, 18, 4, 59, 41, 996577), Decimal('0.84')),
#  (17531, 347, 1, 3026, Decimal('4.99'), datetime.datetime(2007, 2, 20, 10, 16, 26, 996577), Decimal('4.24')),
#  (17532, 347, 1, 3092, Decimal('8.99'), datetime.datetime(2007, 2, 20, 14, 33, 8, 996577), Decimal('7.64'))]

# %% [markdown]
# #### Exercise 4: Conditional Logic with `CASE`
# 1. **Categorize Customers Based on Active Status**:
#    - Create a derived column called `status` to categorize customers as 'Active' or 'Inactive' based on column `active`.
#    - Note that `active` == 0 means the customer was inactive and vice versa

# %%
# %%sql
# SELECT
#     *,
#     CASE
#         WHEN active=0 THEN 'Inactive'
#         WHEN active=1 THEN 'Active'
#         ELSE Null
#     END as status
# from customer
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 599 rows affected.
# [(524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (2, 1, 'Patricia', 'Johnson', 'patricia.johnson@sakilacustomer.org', 6, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (3, 1, 'Linda', 'Williams', 'linda.williams@sakilacustomer.org', 7, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (4, 2, 'Barbara', 'Jones', 'barbara.jones@sakilacustomer.org', 8, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (5, 1, 'Elizabeth', 'Brown', 'elizabeth.brown@sakilacustomer.org', 9, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (6, 2, 'Jennifer', 'Davis', 'jennifer.davis@sakilacustomer.org', 10, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (7, 1, 'Maria', 'Miller', 'maria.miller@sakilacustomer.org', 11, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (8, 2, 'Susan', 'Wilson', 'susan.wilson@sakilacustomer.org', 12, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (9, 2, 'Margaret', 'Moore', 'margaret.moore@sakilacustomer.org', 13, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (10, 1, 'Dorothy', 'Taylor', 'dorothy.taylor@sakilacustomer.org', 14, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (11, 2, 'Lisa', 'Anderson', 'lisa.anderson@sakilacustomer.org', 15, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (12, 1, 'Nancy', 'Thomas', 'nancy.thomas@sakilacustomer.org', 16, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (13, 2, 'Karen', 'Jackson', 'karen.jackson@sakilacustomer.org', 17, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (14, 2, 'Betty', 'White', 'betty.white@sakilacustomer.org', 18, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (15, 1, 'Helen', 'Harris', 'helen.harris@sakilacustomer.org', 19, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (16, 2, 'Sandra', 'Martin', 'sandra.martin@sakilacustomer.org', 20, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 0, 'Inactive'),
#  (17, 1, 'Donna', 'Thompson', 'donna.thompson@sakilacustomer.org', 21, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (18, 2, 'Carol', 'Garcia', 'carol.garcia@sakilacustomer.org', 22, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (19, 1, 'Ruth', 'Martinez', 'ruth.martinez@sakilacustomer.org', 23, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (20, 2, 'Sharon', 'Robinson', 'sharon.robinson@sakilacustomer.org', 24, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (21, 1, 'Michelle', 'Clark', 'michelle.clark@sakilacustomer.org', 25, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (22, 1, 'Laura', 'Rodriguez', 'laura.rodriguez@sakilacustomer.org', 26, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (23, 2, 'Sarah', 'Lewis', 'sarah.lewis@sakilacustomer.org', 27, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (24, 2, 'Kimberly', 'Lee', 'kimberly.lee@sakilacustomer.org', 28, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (25, 1, 'Deborah', 'Walker', 'deborah.walker@sakilacustomer.org', 29, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (26, 2, 'Jessica', 'Hall', 'jessica.hall@sakilacustomer.org', 30, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (27, 2, 'Shirley', 'Allen', 'shirley.allen@sakilacustomer.org', 31, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (28, 1, 'Cynthia', 'Young', 'cynthia.young@sakilacustomer.org', 32, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active'),
#  (29, 2, 'Angela', 'Hernandez', 'angela.hernandez@sakilacustomer.org', 33, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 'Active')]

# %% [markdown]
# 2. **Categorize Payments Based on Amount**:
#    - Create a derived column called `amount_category` to categorize payments as 'Low' (<5), 'Medium' (5-10), or 'High' (>10) based on the `amount` and display the first 10 rows.

# %%
# %%sql
# SELECT
#    *,
#    CASE
#       WHEN amount<5 THEN 'Low'
#       WHEN 5<=amount and amount<=10 THEN 'Medium'
#       WHEN amount>10 THEN 'High'
#       ELSE Null
#    END AS amount_category
# FROM payment
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 14596 rows affected.
# [(17503, 341, 2, 1520, Decimal('7.99'), datetime.datetime(2007, 2, 15, 22, 25, 46, 996577), 'Medium'),
#  (17504, 341, 1, 1778, Decimal('1.99'), datetime.datetime(2007, 2, 16, 17, 23, 14, 996577), 'Low'),
#  (17505, 341, 1, 1849, Decimal('7.99'), datetime.datetime(2007, 2, 16, 22, 41, 45, 996577), 'Medium'),
#  (17506, 341, 2, 2829, Decimal('2.99'), datetime.datetime(2007, 2, 19, 19, 39, 56, 996577), 'Low'),
#  (17507, 341, 2, 3130, Decimal('7.99'), datetime.datetime(2007, 2, 20, 17, 31, 48, 996577), 'Medium'),
#  (17508, 341, 1, 3382, Decimal('5.99'), datetime.datetime(2007, 2, 21, 12, 33, 49, 996577), 'Medium'),
#  (17509, 342, 2, 2190, Decimal('5.99'), datetime.datetime(2007, 2, 17, 23, 58, 17, 996577), 'Medium'),
#  (17510, 342, 1, 2914, Decimal('5.99'), datetime.datetime(2007, 2, 20, 2, 11, 44, 996577), 'Medium'),
#  (17511, 342, 1, 3081, Decimal('2.99'), datetime.datetime(2007, 2, 20, 13, 57, 39, 996577), 'Low'),
#  (17512, 343, 2, 1547, Decimal('4.99'), datetime.datetime(2007, 2, 16, 0, 10, 50, 996577), 'Low'),
#  (17513, 343, 1, 1564, Decimal('6.99'), datetime.datetime(2007, 2, 16, 1, 15, 33, 996577), 'Medium'),
#  (17514, 343, 2, 1879, Decimal('0.99'), datetime.datetime(2007, 2, 17, 1, 26, 0, 996577), 'Low'),
#  (17515, 343, 2, 1922, Decimal('0.99'), datetime.datetime(2007, 2, 17, 4, 32, 51, 996577), 'Low'),
#  (17516, 343, 2, 2461, Decimal('6.99'), datetime.datetime(2007, 2, 18, 18, 26, 38, 996577), 'Medium'),
#  (17517, 343, 1, 2980, Decimal('8.99'), datetime.datetime(2007, 2, 20, 7, 3, 29, 996577), 'Medium'),
#  (17518, 343, 1, 3407, Decimal('0.99'), datetime.datetime(2007, 2, 21, 14, 42, 28, 996577), 'Low'),
#  (17519, 344, 1, 1341, Decimal('3.99'), datetime.datetime(2007, 2, 15, 10, 54, 44, 996577), 'Low'),
#  (17520, 344, 2, 1475, Decimal('4.99'), datetime.datetime(2007, 2, 15, 19, 36, 27, 996577), 'Low'),
#  (17521, 344, 1, 1731, Decimal('0.99'), datetime.datetime(2007, 2, 16, 14, 0, 38, 996577), 'Low'),
#  (17522, 345, 2, 1210, Decimal('0.99'), datetime.datetime(2007, 2, 15, 1, 26, 17, 996577), 'Low'),
#  (17523, 345, 1, 1457, Decimal('4.99'), datetime.datetime(2007, 2, 15, 18, 34, 15, 996577), 'Low'),
#  (17524, 345, 2, 1550, Decimal('0.99'), datetime.datetime(2007, 2, 16, 0, 27, 1, 996577), 'Low'),
#  (17525, 345, 2, 2766, Decimal('4.99'), datetime.datetime(2007, 2, 19, 16, 13, 41, 996577), 'Low'),
#  (17526, 346, 1, 1994, Decimal('5.99'), datetime.datetime(2007, 2, 17, 9, 35, 32, 996577), 'Medium'),
#  (17527, 346, 2, 3372, Decimal('2.99'), datetime.datetime(2007, 2, 21, 12, 2, 45, 996577), 'Low'),
#  (17528, 346, 1, 3421, Decimal('2.99'), datetime.datetime(2007, 2, 21, 15, 51, 24, 996577), 'Low'),
#  (17529, 347, 2, 1711, Decimal('8.99'), datetime.datetime(2007, 2, 16, 12, 40, 18, 996577), 'Medium'),
#  (17530, 347, 2, 2274, Decimal('0.99'), datetime.datetime(2007, 2, 18, 4, 59, 41, 996577), 'Low'),
#  (17531, 347, 1, 3026, Decimal('4.99'), datetime.datetime(2007, 2, 20, 10, 16, 26, 996577), 'Low'),
#  (17532, 347, 1, 3092, Decimal('8.99'), datetime.datetime(2007, 2, 20, 14, 33, 8, 996577), 'Medium')]

# %% [markdown]
# #### Exercise 5: Using Built-in Functions
# 1. **Date Functions**:
#    - Extract the month from the `rental_date` column
#    - The month should be displayed in full month name (e.g., May, June)
#    - Store them in a new column called `rental_month`
#
# > Hint: You can use [TO_CHAR()](https://www.postgresql.org/docs/current/functions-formatting.html) to converts the rental_date to a string representing the full month name.

# %%
# %%sql
# SELECT
#    rental_date
#    , TO_CHAR(rental_date, 'Month') AS rental_month
# FROM rental
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 16044 rows affected.
# [(datetime.datetime(2005, 5, 24, 22, 54, 33), 'May      '),
#  (datetime.datetime(2005, 5, 24, 23, 3, 39), 'May      '),
#  (datetime.datetime(2005, 5, 24, 23, 4, 41), 'May      '),
#  (datetime.datetime(2005, 5, 24, 23, 5, 21), 'May      '),
#  (datetime.datetime(2005, 5, 24, 23, 8, 7), 'May      '),
#  (datetime.datetime(2005, 5, 24, 23, 11, 53), 'May      '),
#  (datetime.datetime(2005, 5, 24, 23, 31, 46), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 0, 40), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 2, 21), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 9, 2), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 19, 27), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 22, 55), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 31, 15), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 39, 22), 'May      '),
#  (datetime.datetime(2005, 5, 25, 0, 43, 11), 'May      '),
#  (datetime.datetime(2005, 5, 25, 1, 6, 36), 'May      '),
#  (datetime.datetime(2005, 5, 25, 1, 10, 47), 'May      '),
#  (datetime.datetime(2005, 5, 25, 1, 17, 24), 'May      '),
#  (datetime.datetime(2005, 5, 25, 1, 48, 41), 'May      '),
#  (datetime.datetime(2005, 5, 25, 1, 59, 46), 'May      '),
#  (datetime.datetime(2005, 5, 25, 2, 19, 23), 'May      '),
#  (datetime.datetime(2005, 5, 25, 2, 40, 21), 'May      '),
#  (datetime.datetime(2005, 5, 25, 2, 53, 2), 'May      '),
#  (datetime.datetime(2005, 5, 25, 3, 21, 20), 'May      '),
#  (datetime.datetime(2005, 5, 25, 3, 36, 50), 'May      '),
#  (datetime.datetime(2005, 5, 25, 3, 41, 50), 'May      '),
#  (datetime.datetime(2005, 5, 25, 3, 42, 37), 'May      '),
#  (datetime.datetime(2005, 5, 25, 3, 47, 12), 'May      '),
#  (datetime.datetime(2005, 5, 25, 4, 1, 32), 'May      '),
#  (datetime.datetime(2005, 5, 25, 4, 5, 17), 'May      ')]

# %% [markdown]
# 2. **String Functions**:
#    - Convert the `first_name` column to uppercase and display the first 10 rows.

# %%
# %%sql
# SELECT
#    first_name,
#    UPPER(first_name) as upper_first_name
# FROM customer
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 10 rows affected.
# [('Jared', 'JARED'),
#  ('Mary', 'MARY'),
#  ('Patricia', 'PATRICIA'),
#  ('Linda', 'LINDA'),
#  ('Barbara', 'BARBARA'),
#  ('Elizabeth', 'ELIZABETH'),
#  ('Jennifer', 'JENNIFER'),
#  ('Maria', 'MARIA'),
#  ('Susan', 'SUSAN'),
#  ('Margaret', 'MARGARET')]

# %% [markdown]
# 3. **Aggregate Functions**:
#    - Calculate the total amount of payments by summing up the `amount` column as `total_pay`.

# %%
# %%sql
# SELECT
#    SUM(amount) AS total_pay
# FROM payment
# Out:
#  * postgresql://postgres:***@localhost:5432/dvdrental
# 1 rows affected.
# [(Decimal('61312.04'),)]

# %% [markdown]
# ## Submission instructions
#
# {rubric: mechanics = 5}
#
# - Make sure the notebook can run from top to bottom without any error. Restart the kernel and run all cells.
# - Commit and push your notebook to the github repo
# - Double check your notebook is rendered properly on Github and you can see all the outputs clearly
# - Submit URL of your Github repo to Moodle under worksheet 3
